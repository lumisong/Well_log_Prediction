# %%
import numpy as np
import lasio
import dlisio
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame
import regex
import seaborn as sns

# %matplotlib inline  
pd.set_option('display.max_rows', 100)
pd.set_option('mode.chained_assignment', None)
mpl.rcParams['figure.dpi'] = 150

# %%
UNWANTED = {'ABDCQF01', 'ABDCQF02', 'ABDCQF03', 'ABDCQF04', 'BVW', 'DRHO', 'NBGRCFM', 'DELTA',
                'GRMAX', 'GRMIN', 'J', 'BADDATA_FLAG', 'KLHC_INT', 'M', 'N', 'PERF_FLAG', 'PORD',
                'RHOFL', 'RHOMA', 'RW', 'SWIRR', 'RD', 'RM', 'RT', 'ROP5_RM', 'RS',
                'PHID', 'ROBB', 'ROBU', 'DRHB', 'DRHU', 'TEMP'}

# %%
MIN_NON_NAN_VALUES = {
    'Well_F19A':  6,
    'Well_F19BT2':  5,
    'Well_F19SR':  4,
    'Well_F1A':  7,
    'Well_F1B':  7,
    'Well_F1C':  7,
    'Well_F1':  7,
    'Well_F11A':  7,
    'Well_F11B':  7,
    'Well_F11':  4,
    'Well_F11T2':  7,
    'Well_F12':  7,
    'Well_F15D':  8,
}

well_files = {
    'Well_F19A': ['./LAS_FILES/15_9-19_A_CPI.LAS'],
    'Well_F19BT2': ['./LAS_FILES/15_9-19_BT2_CPI.LAS'],
    'Well_F19SR': ['./LAS_FILES/15_9-19_SR_CPI.LAS'],
    'Well_F1A': ['./LAS_FILES/15_9-F-1_A_CPO.LAS', './LAS_FILES/15_9-F-1_A_CPI.LAS'],
    'Well_F1B': ['./LAS_FILES/15_9-F-1_B_CPO.LAS', './LAS_FILES/15_9-F-1_B_CPI.LAS'],
    'Well_F1C': ['./LAS_FILES/15_9-F-1_C_CPO.LAS', './LAS_FILES/15_9-F-1_C_CPI.LAS'],
    'Well_F1': ['./LAS_FILES/15_9-F-1_CPO.LAS', './LAS_FILES/15_9-F-1_CPI.LAS'],
    'Well_F11A': ['./LAS_FILES/15_9-F-11_A_CPO.LAS', './LAS_FILES/15_9-F-11_A_CPI.LAS'],
    'Well_F11B': ['./LAS_FILES/15_9-F-11_B_CPO.LAS', './LAS_FILES/15_9-F-11_B_CPI.LAS'],
    'Well_F11': ['./LAS_FILES/15_9-F-11_CPI.LAS'],
    'Well_F11T2': ['./LAS_FILES/15_9-F-11_T2_CPO.LAS', './LAS_FILES/15_9-F-11_T2_CPI.LAS'],
    'Well_F12': ['./LAS_FILES/15_9-F-12_CPO.LAS', './LAS_FILES/15_9-F-12_CPI.LAS'],
    'Well_F15D': ['./LAS_FILES/15_9-F-15D_CPO.LAS', './LAS_FILES/15_9-F-15D_CPI.LAS']
}

well_files_dlts = {
    'Well_F4': ['./LAS_FILES/15_9-F-4_CPI.DLIS', './LAS_FILES/15_9-F-4_CPO.DLIS'],
    'Well_F5': ['./LAS_FILES/15_9-F-5_CPI.DLIS', './LAS_FILES/15_9-F-5_CPO.DLIS'],
    'Well_F10': ['./LAS_FILES/15_9-F-10_CPI.DLIS', './LAS_FILES/15_9-F-10_CPO.DLIS'],
    'Well_F14': ['./LAS_FILES/15_9-F-14_CPI.DLIS', './LAS_FILES/15_9-F-14_CPO.DLIS'],
    'Well_F15': ['./LAS_FILES/15_9-F-15_CPI.DLIS', './LAS_FILES/15_9-F-15_CPO.DLIS'],
    'Well_F15A': ['./LAS_FILES/15_9-F-15A_CPI.DLIS', './LAS_FILES/15_9-F-15A_CPO.DLIS'],
    'Well_F15B': ['./LAS_FILES/15_9-F-15B_CPI.DLIS', './LAS_FILES/15_9-F-15B_CPO.DLIS'],
    'Well_F15C': ['./LAS_FILES/15_9-F-15C_CPI.DLIS', './LAS_FILES/15_9-F-15C_CPO.DLIS'],
}

# %%
tracks_data_and_colors = {
    'GR/CALI/ROP': {
        'columns':[
            {
                'name': 'GR',
                'xlim': (0, 150),
                'xlabel': 'GR (API)'
            },
            {
                'name': 'CALI',
                'xlim': (0, 13),
                'xlabel': 'CALI (In)'
            },
            {
                'name': 'ROP',
                'xlim': (100, 0),
                'xlabel': 'ROP (m/hr)'
            }
        ],
        'palette': ('husl', 3)  
    },
    'NPHI/RHOB': {
        'columns':[
            {
                'name': 'NPHI',
                'xlim': (-0.1, 0.6),
                'xlabel': 'NPHI (v/v)'
            },
            {
                'name': 'RHOB',
                'xlim': (1.5, 3),
                'xlabel': 'RHOB (g/cm3)'
            }
        ],
        'palette': ('Set1', 2)
    },
    'Resistivity': {
        'columns':[
            {
                'name': 'RACEHM',
                'xlim': (0.1, 2000),
                'xlabel': 'RACEHM (ohm.m)',
                'xscale': 'log'
            },
            {
                'name': 'RACELM',
                'xlim': (0.1, 2000),
                'xlabel': 'RACELM (ohm.m)',
                'xscale': 'log'
            },
            {
                'name': 'RM',
                'xlim': (0.1, 2000),
                'xlabel': 'RM (ohm.m)',
                'xscale': 'log'
            },
            {
                'name': 'RD',
                'xlim': (0.1, 2000),
                'xlabel': 'RD (ohm.m)',
                'xscale': 'log'
            }
        ],
        'palette': ('husl', 4)
    },
    'DTC/DTS/PEF': {
        'columns':[
            {
                'name': 'PEF',
                'xlim': (15, 0),
                'xlabel': 'PEF (b/elec)'
            },
            {
                'name': 'DT',
                'xlim': (140, 40),
                'xlabel': 'DT (us/ft)'
            },
            {
                'name': 'DTS',
                'xlim': (240, 40),
                'xlabel': 'DTS (us/ft)'
            }
        ],
        'palette': ('husl', 3)
    },
    'PHIF/VSH/VCARB': {
        'columns':[
            {
                'name': 'PHIF',
                'xlim': (0, 0.5),
                'xlabel': 'PHIF (v/v)'
            },
            {
                'name': 'VSH',
                'xlim': (1.5, 0),
                'xlabel': 'VSH',
                'fill_params': {
                    'y1': 0,
                    'y2': 'VSH',
                    'where': lambda df: df['VSH'] > 0,
                    'color': 'palegoldenrod',
                    'alpha': 0.2
                }
            },
            {
                'name': 'VCARB',
                'xlim': (1.5, 0),
                'xlabel': 'VCARB',
                'fill_params': {
                    'y1': 0,
                    'y2': 'VCARB',
                    'where': lambda df: df['VCARB'] > 0,
                    'color': 'olivedrab',
                    'alpha': 0.2
                }
            }
        ],
        'special_fills': [
            {
                'y1': 0,
                'y2': 'SAND_FLAG',
                'where': lambda df: df['SAND_FLAG'] > 0,
                'color': 'red'
            },
            {
                'y1': 0,
                'y2': 'CARB_FLAG',
                'where': lambda df: df['CARB_FLAG'] > 0,
                'color': 'lime'
            },
            {
                'y1': 0,
                'y2': 'COAL_FLAG',
                'where': lambda df: df['COAL_FLAG'] > 0,
                'color': 'black'
            }
        ],
        'special_fills_xlim': (10, 0),
        'special_fills_xlabel': 'FLAG-SAND|CARB',
        'palette': ('husl', 3)
    },
    'SW': {
        'columns':[
            {
                'name': 'SW',
                'xlim': (0, 1),
                'xlabel': 'SW (v/v)',
                'fill_params': {
                    'y1': 1,
                    'y2': 'SW',
                    'where': lambda df: df['SW'] <= 1,
                    'color': 'green',
                    'alpha': 0.5
                }
            }
        ],
        'palette': ('husl', 1)
    },
    'KLOGH/KLOGV': {
        'columns':[
            {
                'name': 'KLOGH',
                'xlim': (0.01, 10000),
                'xlabel': 'KLOGH (mD)',
                'xscale': 'log'
            },
            {
                'name': 'KLOGV',
                'xlim': (0.01, 10000),
                'xlabel': 'KLOGV (mD)',
                'xscale': 'log'
            }
        ],
        'palette': ('husl', 2)
    }
}

# %%
def read_las_file(fname):
    try:
        las_data = lasio.read(fname)
        return pd.DataFrame(las_data.data, columns=list(las_data.curvesdict.keys()))
    except Exception as e:
        print(f"Error reading file {fname}: {e}")
        return None

def extract_data(fname):

    f,*tail = dlisio.dlis.load(fname)

    logname = list(f.channels)
    name=[]
    for line in logname:
        w = str(line).strip(')').split('(')
        name.append(w[1])

    combined = []
    for n in name:
        frame = f.object('CHANNEL', f'{n}')
        curve = frame.curves()
        if n == 'DEPTH' and frame.units == '0.1 in':
            curve = curve * 0.00254
        combined.append(curve)
    data = DataFrame(combined).T
    data.columns = name
    return data


def process_data(df, fname):
    if match := regex.search(
        r'15_9-19_A_CPI|15_9-19_BT2_CPI|15_9-F-1_C_CPO|15_9-F-12_CPO',
        fname,
    ):
        well_id = match.group()
        if well_id == '15_9-19_A_CPI':
            df['GR'] = df['GRMAX'] - df['VSH']*(df['GRMAX']-df['GRMIN'])
            df['RHOB'] = df['RHOMA'] - df['PORD']*(df['RHOMA']-df['RHOFL'])
            df['NPHI'] = df['PORD'] + (df['PHIF']-df['PORD']-0.01)/0.4
            df['NPHI'] = df['NPHI'].abs()
            df['RPCEHM'] = df['RW']/(df['SW']**(-1/df['N']) * (df['PHIF']+0.01)**(df['M']))
        elif well_id == '15_9-19_BT2_CPI':
            df['RPCEHM'] = df['RW']/(df['SW']**(-1/2.45) * df['PHIF']**1.79)
        elif well_id == '15_9-F-1_C_CPO':
            df = df[df['BADDATA_FLAG'] != 1]
        elif well_id == '15_9-F-12_CPO':
            df.rename(columns={'RT': 'RPCEHM', 'RD': 'RPCELM'}, inplace=True)

    return df

# %%
def merge_datasets(data1, data2=None):
    if data2 is not None:
        return pd.merge_asof(data1, data2, on='DEPTH', allow_exact_matches=True)
    else:
        return data1

def add_or_modify_columns(dt, **kwargs):
    result_df = pd.DataFrame()

    for key, value in kwargs.items():
        temp_df = dt.copy()
        temp_df[key] = Series(np.repeat(value, len(temp_df['DEPTH'])))
        result_df = pd.concat([result_df, temp_df], ignore_index=True)
    return result_df

def rearrange_columns(dt):
    if dt.empty:
        raise ValueError('DataFrame is empty,Cannot rearrange columns.')
    cols = dt.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    return dt[cols]


def calculate_new_step(well_log_df, Well):
    if Well.well['STEP'].value == 0:
        return well_log_df['DEPTH'].diff().mean()
    else:
        return Well.well['STEP'].value

def generate_new_depth_range(well_log_df, Well):
    new_step = calculate_new_step(well_log_df, Well)
    return np.arange(Well.well['STRT'].value, Well.well['STOP'].value + new_step, new_step)

def adjust_depth_data(well_log_df, Well):
    original_depths = np.array(Well['DEPTH'])
    adjust_depths = generate_new_depth_range(well_log_df, Well)
    if np.abs(original_depths - adjust_depths).sum() > 1e-3:
        Well.curves['DEPTH'].data = adjust_depths
        well_log_df['DEPTH'] = adjust_depths
    return well_log_df

def remove_unwanted_columns(dt):
    unwanted_columns = set(dt.columns) & UNWANTED
    return dt.drop(columns=unwanted_columns, inplace=False)

def replace_inf_values(dt):
    dt.replace([np.inf, -np.inf], np.nan, inplace=True)
    return dt

def merge_createname(data1, data2=None, Well=None, **kwargs):
    dt = merge_datasets(data1, data2)
    dt = add_or_modify_columns(dt, **kwargs)
    dt = rearrange_columns(dt)
    if Well is not None:
        dt = adjust_depth_data(dt, Well)
    dt = remove_unwanted_columns(dt)
    dt = replace_inf_values(dt)
    return dt

# %%
def set_plot_style(style="whitegrid", tracks_data_and_colors
                   =None):
    
    sns.set_style(style)
    palettes = {}
    if tracks_data_and_colors is not None:    
        for track_name, track_info in tracks_data_and_colors.items():
            palettes_name, n_colors = track_info['palette']
            palettes[track_name] = sns.color_palette(palettes_name, n_colors)
    return palettes

# %%
def configure_subplots(axs, depths):
    
    axs[0].set_ylabel('Depth (m)')
    for ax in axs:
        ax.set_ylim(depths[0], depths[-1])
        ax.invert_yaxis()
        ax.grid(True)
        ax.locator_params(axis='x', nbins=5)
        ax.get_xaxis().set_visible(False)

# %%
def set_depth_range(well_logs, depth_column, phif_column, depths):

    if depth_column not in well_logs.columns:
        raise ValueError(f"Input DataFrame 'well_logs' must contain a column named '{depth_column}'.")
    if phif_column not in well_logs.columns:
        raise ValueError(f"Input DataFrame 'well_logs' must contain a column named '{phif_column}'.")
    
    min_depth = well_logs[depth_column].min()
    max_depth = well_logs[depth_column].max()
    
    depths = depths or [min_depth, max_depth]
    
    if depths[0] in ['TOP', 'topfm']:
        first_valid_index = well_logs[phif_column].first_valid_index()
        if first_valid_index is not None:
            depths[0] = well_logs[depth_column][first_valid_index]
            if depths[0] >= max_depth:
                depths[0] = min_depth
    
    if depths[-1] in ['BOTTOM', 'bottomfm']:
        last_valid_index = well_logs[phif_column].last_valid_index()
        if last_valid_index is not None:
            depths[-1] = max(well_logs[depth_column][last_valid_index], max_depth)
    
    depths[0] = max(depths[0], min_depth)
    depths[-1] = min(depths[-1], max_depth)
    
    return depths

# %%
def create_subplots(nrows=1, ncols=7, figsize=(15, 10), wspace=0.25, hspace=0.2,
                    sharex=True, sharey=True, subplot_titles=None,
                    xlabel=None, ylabel=None):
    fig, axs = plt.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
                            figsize=figsize, gridspec_kw={'wspace': wspace, 'hspace': hspace})
    fig.subplots_adjust(left=0.05, bottom=0.05, right=0.975, top=0.7, wspace=wspace, hspace=hspace)
    
    if subplot_titles is not None:
        for ax, title in zip(axs.flatten(), subplot_titles):
            ax.set_title(title)
    
    if xlabel is not None:
        for ax in axs.flatten():
            ax.set_xlabel(xlabel)
    
    if ylabel is not None:
        for ax in axs.flatten():
            ax.set_ylabel(ylabel)
    
    return fig, axs

# %%
def plot_track(ax, well_logs, track_info, palettes, track_name):
   
    track_columns = track_info['columns']
    track_colors = palettes.get(track_name, [])
    
    track_special_fills = track_info.get('special_fills', [])
    
    spine_position = 1.0 - 0.075
    
    for i, column_info in enumerate(track_columns):
        
        column_name = column_info['name']
        xlim = column_info['xlim']
        xlabel = column_info['xlabel']
        color = track_colors[i] if track_colors else 'blue' 

        ax_columns = ax.twiny()
        ax_columns.plot(well_logs[column_name], well_logs.DEPTH, '-', color=color)
        ax_columns.set_xlim(*xlim)
        ax_columns.set_xlabel(xlabel, color=color)
        ax_columns.minorticks_on()
        ax_columns.tick_params(axis='x', color=color)

        if column_info.get('xscale','linear') == 'log':
            ax_columns.set_xscale('log')

        if fill_params := column_info.get('fill_params'):
            y1 = fill_params.get('y1', 0)
            y2 = well_logs[fill_params.get('y2', column_name)]

            if where_condition := fill_params.get('where'):
                where = where_condition(well_logs) # Evaluate the lambda function
            else:
                where = None
            color = fill_params.get('color', 'blue')
            alpha = fill_params.get('alpha', 0.5)
            ax_columns.fill_betweenx(well_logs.DEPTH, y2, y1, where=where, color=color, alpha=alpha)

            ax_columns.fill_betweenx(well_logs.DEPTH, y2, y1, where=where, color=color, alpha=alpha)

        spine_position += 0.075
        ax_columns.spines['top'].set_position(("axes", spine_position))
    
    if track_special_fills:
        special_fills_xlim = track_info['special_fills_xlim']
        special_fills_xlabel = track_info['special_fills_xlabel']
        ax_special_fills = ax.twiny()
        ax_special_fills.set_xlim(*special_fills_xlim)
        ax_special_fills.set_xlabel(special_fills_xlabel)
        ax_special_fills.minorticks_on()
        ax_special_fills.tick_params(axis='x')
        
        for special_fill in track_special_fills:
            
            y1 = special_fill.get('y1', 0)
            y2 = well_logs[special_fill.get('y2', column_name)]
            if  where_condition := special_fill.get('where'):
                where = where_condition(well_logs)
            else:
                where = None
            color = special_fill.get('color', 'blue')
            ax_special_fills.fill_betweenx(well_logs.DEPTH, y2, y1, where=where, color=color)

        spine_position += 0.075
        ax_special_fills.spines['top'].set_position(("axes", spine_position))

# %%
def save_figure(fig, savefile):
    if len(savefile) > 0:
        fig.savefig(savefile, dpi=300)

# %%
def well_log_plot(well_logs,**kwargs):

    depths = set_depth_range(well_logs,'DEPTH','PHIF',kwargs.get('depths',[]))

    palettes = set_plot_style(style='ticks',tracks_data_and_colors=tracks_data_and_colors)

    fig, axs = create_subplots(nrows=1, ncols=7, figsize=(15, 10), wspace=0.25,hspace=0.2,sharex=True, sharey=True,subplot_titles=None,xlabel=None, ylabel=None)

    configure_subplots(axs, depths)
    
    track_name_to_index = {track_name: index for index, track_name in enumerate(tracks_data_and_colors.keys())}

    for track_name, track_info in tracks_data_and_colors.items():
        ax_index = track_name_to_index[track_name]
        ax = axs[ax_index]
        plot_track(ax, well_logs, track_info, palettes, track_name)

    fig.suptitle(
        f"Log Petrophysical display for {well_logs.iloc[0]['name']}",
        weight='bold',
        fontsize=20,
        y=0.925,
    )

    save_figure(fig, kwargs.get('savefile',""))

# %%
well_data = {}

for well_name, files in well_files.items():
    if len(files) == 1:
        fname = files[0]
        las_data = lasio.read(fname)
        df = read_las_file(fname)
        df = process_data(df, fname)
        df = merge_createname(df, None, las_data, name=well_name)
        del las_data
    elif len(files) ==  2:
        fname1, fname2 = files
        las_data1 = lasio.read(fname1)
        df1 = read_las_file(fname1)
        las_data2 = lasio.read(fname2)
        df2 = read_las_file(fname2)
        df1 = process_data(df1, fname)
        df2 = process_data(df2, fname)
        df = merge_createname(df2, df1, las_data2, name=well_name)
        del las_data1, las_data2, df1, df2
    else:
        print(f"Unexpected number of files for well {well_name}")
        continue
    df.dropna(thresh=MIN_NON_NAN_VALUES[well_name], inplace=True)
    well_data[well_name] = df
# Out:
# Only engine='normal' can read wrapped files
# Only engine='normal' can read wrapped files

# %%
for well_name, df in well_data.items():
    print("--------------------")
    print(f"{well_name}:")
    display(df)
# Out:
# --------------------
# Well_F19A:
#            name      DEPTH   BS  CARB_FLAG  COAL_FLAG   KLOGH      PHIF  \
# 0     Well_F19A  3666.5916  8.5        0.0        0.0  0.0003  0.199843
# 1     Well_F19A  3666.7440  8.5        0.0        0.0  0.0000  0.218743
# 2     Well_F19A  3666.8964  8.5        0.0        0.0  0.0000  0.242380
# 3     Well_F19A  3667.0488  8.5        0.0        0.0  0.0000  0.226408
# 4     Well_F19A  3667.2012  8.5        0.0        0.0  0.0000  0.216169
# ...         ...        ...  ...        ...        ...     ...       ...
# 3003  Well_F19A  4124.2488  8.5        0.0        0.0     NaN       NaN
# 3004  Well_F19A  4124.4012  8.5        0.0        0.0     NaN       NaN
# 3005  Well_F19A  4124.5536  8.5        0.0        0.0     NaN       NaN
# 3006  Well_F19A  4124.7060  8.5        0.0        0.0     NaN       NaN
# 3007  Well_F19A  4124.8584  8.5        0.0        0.0     NaN       NaN
#
#       SAND_FLAG      SW       VSH         GR      RHOB      NPHI    RPCEHM
# 0           0.0  0.5590  0.598800  54.521200  2.288292  0.174843  0.279271
# 1           0.0  0.5131  0.599555  54.444945  2.253138  0.193743  0.231091
# 2           0.0  0.4737  0.600310  54.368690  2.209173  0.217380  0.187570
# 3           0.0  0.5054  0.601065  54.292435  2.238881  0.201408  0.216499
# 4           0.0  0.5360  0.601820  54.216180  2.257926  0.191169  0.240041
# ...         ...     ...       ...        ...       ...       ...       ...
# 3003        NaN     NaN  0.422817        NaN       NaN       NaN       NaN
# 3004        NaN     NaN  0.422817        NaN       NaN       NaN       NaN
# 3005        NaN     NaN  0.422817        NaN       NaN       NaN       NaN
# 3006        NaN     NaN  0.422817        NaN       NaN       NaN       NaN
# 3007        NaN     NaN  0.422817        NaN       NaN       NaN       NaN
#
# [2692 rows x 14 columns]
# --------------------
# Well_F19BT2:
#              name      DEPTH  CARB_FLAG  COAL_FLAG   KLOGH   KLOGV      PHIF  \
# 0     Well_F19BT2  3768.0900        0.0        0.0  0.0002  0.0001  0.034643
# 1     Well_F19BT2  3768.2424        0.0        0.0  0.0001  0.0000  0.032957
# 2     Well_F19BT2  3768.3948        0.0        0.0  0.0000  0.0000  0.010825
# 3     Well_F19BT2  3768.5472        0.0        0.0  0.0000  0.0000  0.017037
# 4     Well_F19BT2  3768.6996        0.0        0.0  0.0000  0.0000  0.044282
# ...           ...        ...        ...        ...     ...     ...       ...
# 2921  Well_F19BT2  4213.2504        0.0        0.0  1.6794  0.9829  0.154233
# 2922  Well_F19BT2  4213.4028        0.0        0.0  4.9892  3.1228  0.165129
# 2923  Well_F19BT2  4213.5552        0.0        0.0  0.8535  0.4791  0.134326
# 2924  Well_F19BT2  4213.7076        0.0        0.0  0.9916  0.5618  0.135998
# 2925  Well_F19BT2  4213.8600        0.0        0.0  0.6039  0.3319  0.130864
#
#       SAND_FLAG      SW     VSH     RPCEHM
# 0           0.0  1.0000  0.6610   8.830042
# 1           0.0  1.0000  0.6946   9.654684
# 2           0.0  1.0000  0.7812  70.831481
# 3           0.0  1.0000  0.9155  31.452015
# 4           0.0  1.0000  0.9545   5.689620
# ...         ...     ...     ...        ...
# 2921        0.0  0.8036  0.8552   0.518147
# 2922        0.0  0.8901  0.7930   0.478077
# 2923        0.0  1.0000  0.6836   0.725473
# 2924        0.0  1.0000  0.6778   0.709571
# 2925        0.0  0.9827  0.7033   0.754756
#
# [2926 rows x 11 columns]
# --------------------
# Well_F19SR:
#             name      DEPTH      BWV      DT  KLOGH  KLOGV  PHIF  SAND_FLAG  \
# 1     Well_F19SR  3549.8532  0.08183  54.594    NaN    NaN   NaN        NaN
# 2     Well_F19SR  3550.0056  0.08183  54.594    NaN    NaN   NaN        NaN
# 3     Well_F19SR  3550.1580  0.08183  54.594    NaN    NaN   NaN        NaN
# 4     Well_F19SR  3550.3104  0.08183  54.594    NaN    NaN   NaN        NaN
# 5     Well_F19SR  3550.4628  0.08183  54.594    NaN    NaN   NaN        NaN
# ...          ...        ...      ...     ...    ...    ...   ...        ...
# 7007  Well_F19SR  4617.5676  0.00000  40.000    0.0    NaN   0.0        0.0
# 7008  Well_F19SR  4617.7200  0.00000  40.000    0.0    NaN   0.0        0.0
# 7009  Well_F19SR  4617.8724  0.00000  40.000    0.0    NaN   0.0        0.0
# 7010  Well_F19SR  4618.0248  0.00000  40.000    0.0    NaN   0.0        0.0
# 7011  Well_F19SR  4618.1772  0.00000  40.000    0.0    NaN   0.0        0.0
#
#        SW  VSH
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN
# 5     NaN  NaN
# ...   ...  ...
# 7007  1.0  NaN
# 7008  1.0  NaN
# 7009  1.0  NaN
# 7010  1.0  NaN
# 7011  1.0  NaN
#
# [7011 rows x 10 columns]
# --------------------
# Well_F1A:
#            name   DEPTH    BS  CALI  DT  DTS        GR  NPHI  PEF  RACEHM  \
# 801    Well_F1A   226.0  26.0   NaN NaN  NaN   13.8931   NaN  NaN  0.7782
# 802    Well_F1A   226.1  26.0   NaN NaN  NaN   16.8323   NaN  NaN  0.8146
# 803    Well_F1A   226.2  26.0   NaN NaN  NaN   19.4866   NaN  NaN  0.8264
# 804    Well_F1A   226.3  26.0   NaN NaN  NaN   21.0532   NaN  NaN  0.8416
# 805    Well_F1A   226.4  26.0   NaN NaN  NaN   23.6296   NaN  NaN  0.8546
# ...         ...     ...   ...   ...  ..  ...       ...   ...  ...     ...
# 35281  Well_F1A  3674.0   8.5   NaN NaN  NaN  116.3081   NaN  NaN     NaN
# 35282  Well_F1A  3674.1   8.5   NaN NaN  NaN  116.6003   NaN  NaN     NaN
# 35283  Well_F1A  3674.2   8.5   NaN NaN  NaN  116.8855   NaN  NaN     NaN
# 35284  Well_F1A  3674.3   8.5   NaN NaN  NaN  113.8785   NaN  NaN     NaN
# 35285  Well_F1A  3674.4   8.5   NaN NaN  NaN  110.8716   NaN  NaN     NaN
#
#        ...      ROP  RPCEHM  RPCELM  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  SW  \
# 801    ...  10.1142  0.6478  0.7380        NaN    NaN   NaN        NaN NaN
# 802    ...  15.9918  0.8090  0.8258        NaN    NaN   NaN        NaN NaN
# 803    ...  21.8538  0.9507  0.9058        NaN    NaN   NaN        NaN NaN
# 804    ...  22.3173  1.0518  0.9406        NaN    NaN   NaN        NaN NaN
# 805    ...  22.7807  1.0162  0.9325        NaN    NaN   NaN        NaN NaN
# ...    ...      ...     ...     ...        ...    ...   ...        ...  ..
# 35281  ...  10.7355     NaN     NaN        0.0    NaN   NaN        NaN NaN
# 35282  ...  10.7248     NaN     NaN        0.0    NaN   NaN        NaN NaN
# 35283  ...  10.7252     NaN     NaN        0.0    NaN   NaN        NaN NaN
# 35284  ...  10.7256     NaN     NaN        0.0    NaN   NaN        NaN NaN
# 35285  ...  10.7259     NaN     NaN        0.0    NaN   NaN        NaN NaN
#
#        VCARB     VSH
# 801      NaN     NaN
# 802      NaN     NaN
# 803      NaN     NaN
# 804      NaN     NaN
# 805      NaN     NaN
# ...      ...     ...
# 35281    NaN  0.8516
# 35282    NaN  0.8540
# 35283    NaN  0.8563
# 35284    NaN  0.8324
# 35285    NaN  0.8086
#
# [34223 rows x 22 columns]
# --------------------
# Well_F1B:
#            name   DEPTH    BS  CALI  DT  DTS       GR  NPHI  PEF  RACEHM  ...  \
# 24435  Well_F1B  2589.4  17.5   NaN NaN  NaN  73.4230   NaN  NaN  0.2521  ...
# 24436  Well_F1B  2589.5  17.5   NaN NaN  NaN  78.6534   NaN  NaN  0.2366  ...
# 24437  Well_F1B  2589.6  17.5   NaN NaN  NaN  82.2872   NaN  NaN  0.2222  ...
# 39448  Well_F1C  4090.7   8.5   NaN  117.6952   NaN  NaN     NaN     NaN
# 39449  Well_F1C  4090.8   8.5   NaN  119.5765   NaN  NaN     NaN     NaN
#
#        RHOB      ROP      RPCEHM      RPCELM  COAL_FLAG  KLOGH  PHIF  \
# 11969   NaN  21.6686    592.2389  96977.2891        NaN    NaN   NaN
# 11970   NaN  23.7149  65166.3477  64796.1680        NaN    NaN   NaN
# 11971   NaN  25.7612  97365.9063  97036.4063        NaN    NaN   NaN
# 11972   NaN  27.8046    556.3832  97036.4063        NaN    NaN   NaN
# 11973   NaN  28.6198    588.2989  96977.6406        NaN    NaN   NaN
# ...     ...      ...         ...         ...        ...    ...   ...
# 39445   NaN  29.9197         NaN         NaN        0.0    NaN   NaN
# 39446   NaN  29.9273         NaN         NaN        0.0    NaN   NaN
# 39447   NaN  29.9291         NaN         NaN        0.0    NaN   NaN
# 39448   NaN  29.9309         NaN         NaN        0.0    NaN   NaN
# 39449   NaN  29.9327         NaN         NaN        0.0    NaN   NaN
#
#        SAND_FLAG  SW  VCARB     VSH
# 11969        NaN NaN    NaN     NaN
# 11970        NaN NaN    NaN     NaN
# 11971        NaN NaN    NaN     NaN
# 11972        NaN NaN    NaN     NaN
# 11973        NaN NaN    NaN     NaN
# ...          ...  ..    ...     ...
# 39445        0.0 NaN    NaN  1.0000
# 39446        0.0 NaN    NaN  0.9748
# 39447        0.0 NaN    NaN  0.9696
# 39448        0.0 NaN    NaN  0.9796
# 39449        0.0 NaN    NaN  0.9962
#
# [27354 rows x 20 columns]
# --------------------
# Well_F1:
#           name   DEPTH    BS  CALI  DT        GR  NPHI  PEF  RACEHM  RACELM  \
# 700    Well_F1   215.9  36.0   NaN NaN    8.7677   NaN  NaN  0.5405  0.2689
# 701    Well_F1   216.0  36.0   NaN NaN    7.9519   NaN  NaN  0.5642  0.3064
# 702    Well_F1   216.1  36.0   NaN NaN    6.5373   NaN  NaN  0.4250  0.2993
# 703    Well_F1   216.2  36.0   NaN NaN    5.8048   NaN  NaN  0.4877  0.3420
# 704    Well_F1   216.3  36.0   NaN NaN    6.3505   NaN  NaN  0.5296  0.2663
# ...        ...     ...   ...   ...  ..       ...   ...  ...     ...     ...
# 34779  Well_F1  3623.8   8.5   NaN NaN  106.8823   NaN  NaN     NaN     NaN
# 34780  Well_F1  3623.9   8.5   NaN NaN  109.7547   NaN  NaN     NaN     NaN
# 34781  Well_F1  3624.0   8.5   NaN NaN  113.8085   NaN  NaN     NaN     NaN
# 34782  Well_F1  3624.1   8.5   NaN NaN  116.7465   NaN  NaN     NaN     NaN
# 34783  Well_F1  3624.2   8.5   NaN NaN  119.2240   NaN  NaN     NaN     NaN
#
#        ...      ROP  RPCEHM  RPCELM  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  SW  \
# 700    ...      NaN  0.1942  0.8712        NaN    NaN   NaN        NaN NaN
# 701    ...      NaN  0.1993  0.9572        NaN    NaN   NaN        NaN NaN
# 702    ...      NaN  0.1755  0.9183        NaN    NaN   NaN        NaN NaN
# 703    ...      NaN  0.1373  0.9427        NaN    NaN   NaN        NaN NaN
# 704    ...      NaN  0.1106  0.7757        NaN    NaN   NaN        NaN NaN
# ...    ...      ...     ...     ...        ...    ...   ...        ...  ..
# 34779  ...  15.0267     NaN     NaN        NaN    NaN   NaN        NaN NaN
# 34780  ...  15.0186     NaN     NaN        NaN    NaN   NaN        NaN NaN
# 34781  ...  15.0105     NaN     NaN        NaN    NaN   NaN        NaN NaN
# 34782  ...  15.0183     NaN     NaN        NaN    NaN   NaN        NaN NaN
# 34783  ...  15.0260     NaN     NaN        NaN    NaN   NaN        NaN NaN
#
#        VCARB     VSH
# 700      NaN     NaN
# 701      NaN     NaN
# 702      NaN     NaN
# 703      NaN     NaN
# 704      NaN     NaN
# ...      ...     ...
# 34779    0.0  0.7656
# 34780    0.0  0.7896
# 34781    0.0  0.8234
# 34782    0.0  0.8478
# 34783    0.0  0.8685
#
# [33826 rows x 21 columns]
# --------------------
# Well_F11A:
#             name   DEPTH    BS  CALI  DT  DTS      GR  NPHI  PEF  RACEHM  ...  \
# 23771  Well_F11A  2565.6  17.5   NaN NaN  NaN  51.620   NaN  NaN   0.150  ...
# 23772  Well_F11A  2565.7  17.5   NaN NaN  NaN  55.199   NaN  NaN   0.148  ...
# 23773  Well_F11A  2565.8  17.5   NaN NaN  NaN  55.820   NaN  NaN   0.143  ...
# 23774  Well_F11A  2565.9  17.5   NaN NaN  NaN  56.663   NaN  NaN   0.135  ...
# 23775  Well_F11A  2566.0  17.5   NaN NaN  NaN  57.969   NaN  NaN   0.141  ...
# ...          ...     ...   ...   ...  ..  ...     ...   ...  ...     ...  ...
# 35644  Well_F11A  3752.9   8.5   NaN NaN  NaN     NaN   NaN  NaN   0.716  ...
# 35645  Well_F11A  3753.0   8.5   NaN NaN  NaN     NaN   NaN  NaN   0.683  ...
# 35646  Well_F11A  3753.1   8.5   NaN NaN  NaN     NaN   NaN  NaN   0.676  ...
# 35647  Well_F11A  3753.2   8.5   NaN NaN  NaN     NaN   NaN  NaN   0.682  ...
# 35648  Well_F11A  3753.3   8.5   NaN NaN  NaN     NaN   NaN  NaN   0.689  ...
#
#           ROP  RPCEHM  RPCELM  CARB_FLAG  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  \
# 23771  10.038     NaN     NaN        NaN        NaN    NaN   NaN        NaN
# 23772  10.032     NaN     NaN        NaN        NaN    NaN   NaN        NaN
# 23773  10.026     NaN     NaN        NaN        NaN    NaN   NaN        NaN
# 23774  10.020     NaN     NaN        NaN        NaN    NaN   NaN        NaN
# 23775  10.024     NaN     NaN        NaN        NaN    NaN   NaN        NaN
# ...       ...     ...     ...        ...        ...    ...   ...        ...
# 35644  19.743   0.579   0.657        NaN        0.0    NaN   NaN        NaN
# 35645  19.760   0.618   0.673        NaN        0.0    NaN   NaN        NaN
# 35646  19.761   0.664   0.694        NaN        0.0    NaN   NaN        NaN
# 35647  19.762   0.715   0.717        NaN        0.0    NaN   NaN        NaN
# 35648  19.762   0.741   0.737        NaN        0.0    NaN   NaN        NaN
#
#        SW  VSH
# 23771 NaN  NaN
# 23772 NaN  NaN
# 23773 NaN  NaN
# 23774 NaN  NaN
# 23775 NaN  NaN
# ...    ..  ...
# 35644 NaN  NaN
# 35645 NaN  NaN
# 35646 NaN  NaN
# 35647 NaN  NaN
# 35648 NaN  NaN
#
# [11878 rows x 22 columns]
# --------------------
# Well_F11B:
#             name   DEPTH    BS  CALI      GR  NPHI  PEF  RACEHM  RACELM  RHOB  \
# 23783  Well_F11B  2566.8  17.5   NaN  59.093   NaN  NaN   0.219   0.072   NaN
# 23784  Well_F11B  2566.9  17.5   NaN  60.980   NaN  NaN   0.229   0.073   NaN
# 23785  Well_F11B  2567.0  17.5   NaN  59.999   NaN  NaN   0.223   0.072   NaN
# 23786  Well_F11B  2567.1  17.5   NaN  62.746   NaN  NaN   0.225   0.072   NaN
# 23787  Well_F11B  2567.2  17.5   NaN  61.462   NaN  NaN   0.234   0.072   NaN
# ...          ...     ...   ...   ...     ...   ...  ...     ...     ...   ...
# 45724  Well_F11B  4760.9   8.5   NaN     NaN   NaN  NaN   2.492   2.283   NaN
# 45725  Well_F11B  4761.0   8.5   NaN     NaN   NaN  NaN   2.326   2.177   NaN
# 45726  Well_F11B  4761.1   8.5   NaN     NaN   NaN  NaN   2.229   2.125   NaN
# 45727  Well_F11B  4761.2   8.5   NaN     NaN   NaN  NaN   2.154   2.063   NaN
# 45728  Well_F11B  4761.3   8.5   NaN     NaN   NaN  NaN   2.069   2.007   NaN
#
#           ROP     RPCEHM     RPCELM  CARB_FLAG  COAL_FLAG  KLOGH  PHIF  \
# 23783  10.027    603.657    122.379        NaN        NaN    NaN   NaN
# 23784  10.031  56238.168  27802.186        NaN        NaN    NaN   NaN
# 23785  10.034  49266.934  36701.152        NaN        NaN    NaN   NaN
# 23786  10.038  15291.530  14162.380        NaN        NaN    NaN   NaN
# 23787  10.039  69757.789    238.071        NaN        NaN    NaN   NaN
# ...       ...        ...        ...        ...        ...    ...   ...
# 45724  31.543      2.373      2.257        NaN        NaN    NaN   NaN
# 45725  30.856      2.096      2.080        NaN        NaN    NaN   NaN
# 45726  30.133      1.817      1.919        NaN        NaN    NaN   NaN
# 45727  29.409      1.656      1.793        NaN        NaN    NaN   NaN
# 45728  28.688      1.611      1.746        NaN        NaN    NaN   NaN
#
#        SAND_FLAG  SW    VSH
# 23783        NaN NaN    NaN
# 23784        NaN NaN    NaN
# 23785        NaN NaN    NaN
# 23786        NaN NaN    NaN
# 23787        NaN NaN    NaN
# ...          ...  ..    ...
# 45724        NaN NaN  0.776
# 45725        NaN NaN  0.776
# 45726        NaN NaN  0.776
# 45727        NaN NaN  0.776
# 45728        NaN NaN  0.776
#
# [21775 rows x 20 columns]
# --------------------
# Well_F11:
#           name  DEPTH    BS   GR  RACEHM  RACELM     ROP  RPCEHM  RPCELM
# 0     Well_F11  188.5  36.0  4.3     NaN     NaN     NaN     NaN     NaN
# 1     Well_F11  188.6  36.0  3.8     NaN     NaN     NaN     NaN     NaN
# 2     Well_F11  188.7  36.0  4.3     NaN     NaN     NaN     NaN     NaN
# 3     Well_F11  188.8  36.0  4.6     NaN     NaN     NaN     NaN     NaN
# 4     Well_F11  188.9  36.0  4.6     NaN     NaN     NaN     NaN     NaN
# ...        ...    ...   ...  ...     ...     ...     ...     ...     ...
# 1578  Well_F11  346.3  26.0  NaN     NaN     NaN  42.111     NaN     NaN
# 1579  Well_F11  346.4  26.0  NaN     NaN     NaN  41.886     NaN     NaN
# 1580  Well_F11  346.5  26.0  NaN     NaN     NaN  41.660     NaN     NaN
# 1581  Well_F11  346.6  26.0  NaN     NaN     NaN  41.463     NaN     NaN
# 1582  Well_F11  346.7  26.0  NaN     NaN     NaN  41.069     NaN     NaN
#
# [1545 rows x 9 columns]
# --------------------
# Well_F11T2:
#              name   DEPTH    BS  CALI  DT  DTS    GR  NPHI  PEF  RACEHM  ...  \
# 520    Well_F11T2   240.5  26.0   NaN NaN  NaN  24.1   NaN  NaN   1.267  ...
# 521    Well_F11T2   240.6  26.0   NaN NaN  NaN  23.9   NaN  NaN   1.361  ...
# 522    Well_F11T2   240.7  26.0   NaN NaN  NaN  23.8   NaN  NaN   1.472  ...
# 523    Well_F11T2   240.8  26.0   NaN NaN  NaN  24.1   NaN  NaN   1.609  ...
# 524    Well_F11T2   240.9  26.0   NaN NaN  NaN  23.7   NaN  NaN   1.808  ...
# ...           ...     ...   ...   ...  ..  ...   ...   ...  ...     ...  ...
# 43641  Well_F11T2  4552.6   8.5   NaN NaN  NaN   NaN   NaN  NaN   1.021  ...
# 43642  Well_F11T2  4552.7   8.5   NaN NaN  NaN   NaN   NaN  NaN   1.016  ...
# 43643  Well_F11T2  4552.8   8.5   NaN NaN  NaN   NaN   NaN  NaN   0.994  ...
# 43644  Well_F11T2  4552.9   8.5   NaN NaN  NaN   NaN   NaN  NaN   0.975  ...
# 43645  Well_F11T2  4553.0   8.5   NaN NaN  NaN   NaN   NaN  NaN   0.967  ...
#
#           ROP  RPCEHM  RPCELM  CARB_FLAG  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  \
# 520     8.488   2.194   1.692        NaN        NaN    NaN   NaN        NaN
# 521     8.498   2.346   1.824        NaN        NaN    NaN   NaN        NaN
# 522     8.471   2.393   1.918        NaN        NaN    NaN   NaN        NaN
# 523     8.444   2.327   1.991        NaN        NaN    NaN   NaN        NaN
# 524     8.417   2.405   2.112        NaN        NaN    NaN   NaN        NaN
# ...       ...     ...     ...        ...        ...    ...   ...        ...
# 43641  14.957   1.112   1.114        NaN        0.0    NaN   NaN        NaN
# 43642  14.950   1.142   1.122        NaN        0.0    NaN   NaN        NaN
# 43643  14.943   1.139   1.112        NaN        0.0    NaN   NaN        NaN
# 43644  14.949   1.058   1.082        NaN        0.0    NaN   NaN        NaN
# 43645  14.954   0.985   1.064        NaN        0.0    NaN   NaN        NaN
#
#        SW  VSH
# 520   NaN  NaN
# 521   NaN  NaN
# 522   NaN  NaN
# 523   NaN  NaN
# 524   NaN  NaN
# ...    ..  ...
# 43641 NaN  NaN
# 43642 NaN  NaN
# 12172   NaN  26.0154  97400.3047  97036.4063        NaN    NaN   NaN
# 12173   NaN  25.5846  74109.7109  97036.4063        NaN    NaN   NaN
# 12174   NaN  25.1773  97543.4219  97036.4063        NaN    NaN   NaN
# 12175   NaN  24.8136  97465.2578  97036.4063        NaN    NaN   NaN
# 12176   NaN  24.5163  84680.6016  97036.4063        NaN    NaN   NaN
# ...     ...      ...         ...         ...        ...    ...   ...
# 45287   NaN  31.1314      4.0685      3.7719        0.0    NaN   NaN
# 45288   NaN  31.1326      4.0661      3.7322        0.0    NaN   NaN
# 45289   NaN  31.1343      4.0411      3.6849        0.0    NaN   NaN
# 45290   NaN  31.1368      3.9779      3.6250        0.0    NaN   NaN
# 45291   NaN  31.1407      3.8742      3.4981        0.0    NaN   NaN
#
#        SAND_FLAG  SW  VCARB  VSH
# 12172        NaN NaN    NaN  NaN
# 12173        NaN NaN    NaN  NaN
# 12174        NaN NaN    NaN  NaN
# 12175        NaN NaN    NaN  NaN
# 12176        NaN NaN    NaN  NaN
# ...          ...  ..    ...  ...
# 45287        NaN NaN    NaN  NaN
# 45288        NaN NaN    NaN  NaN
# 45289        NaN NaN    NaN  NaN
# 45290        NaN NaN    NaN  NaN
# 45291        NaN NaN    NaN  NaN
#
# [32874 rows x 20 columns]

# %%
well_data_dlts = {}

for well_name, files in well_files_dlts.items():
    if len(files) ==  2:
        fname1, fname2 = files
        # CPI文件
        df1 = extract_data(fname1)
        df1.rename(columns={'RT': 'RPCEHM', 'RD': 'RPCELM'}, inplace=True)
        # CPO文件
        df2 = extract_data(fname2)
        if well_name == 'Well_F10':
            df2.drop(['RHOB'], axis=1, inplace=True)
        df = merge_createname(df1, df2, name=well_name)
        del df1, df2
    else:
        print(f"Unexpected number of files for well {well_name}")
        continue
    
    well_data_dlts[well_name] = df

# %%
for well_name, df in well_data_dlts.items():
    print("--------------------")
    print(f"{well_name}:")
    display(df)
# Out:
# --------------------
# Well_F4:
#           name      DEPTH      DT     DTS   GR    NPHI  RPCELM    RHOB  \
# 0      Well_F4   200.2536 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 1      Well_F4   200.4060 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 2      Well_F4   200.5584 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 3      Well_F4   200.7108 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 4      Well_F4   200.8632 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# ...        ...        ...     ...     ...  ...     ...     ...     ...
# 21818  Well_F4  3525.3168 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 21819  Well_F4  3525.4692 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 21820  Well_F4  3525.6216 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 21821  Well_F4  3525.7740 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
# 21822  Well_F4  3525.9264 -999.25 -999.25  1.0 -999.25 -999.25 -999.25
#
#        RPCEHM  CARB_FLAG  COAL_FLAG   KLOGH    PHIF  SAND_FLAG      SW  \
# 26837    2.569  2.6100    2.915    -999.25    -999.25 -999.250 -999.250000
#
#        SAND_FLAG      SW       VSH
# 0            NaN     NaN       NaN
# 1            NaN     NaN       NaN
# 2            NaN     NaN       NaN
# 3            NaN     NaN       NaN
# 4            NaN     NaN       NaN
# ...          ...     ...       ...
# 26833       0.00    1.00    0.6401
# 26834       0.00    1.00    0.6401
# 26835       0.00    1.00    0.6401
# 26836       0.00    1.00    0.6401
# 26837    -999.25 -999.25 -999.2500
#
# [26838 rows x 17 columns]
# --------------------
# Well_F15A:
#             name      DEPTH    CALI      DT          GR    NPHI     PEF  \
# 0      Well_F15A   216.8652 -999.25 -999.25   11.647100 -999.25 -999.25
# 1      Well_F15A   217.0176 -999.25 -999.25   11.647100 -999.25 -999.25
# 2      Well_F15A   217.1700 -999.25 -999.25   13.588300 -999.25 -999.25
# 3      Well_F15A   217.3224 -999.25 -999.25    7.764700 -999.25 -999.25
# 4      Well_F15A   217.4748 -999.25 -999.25   11.647100 -999.25 -999.25
# ...          ...        ...     ...     ...         ...     ...     ...
# 25384  Well_F15A  4085.3868 -999.25 -999.25  280.380798 -999.25 -999.25
# 25385  Well_F15A  4085.5392 -999.25 -999.25  378.918793 -999.25 -999.25
# 25386  Well_F15A  4085.6916 -999.25 -999.25  378.918793 -999.25 -999.25
# 25387  Well_F15A  4085.8440 -999.25 -999.25  378.918793 -999.25 -999.25
# 25388  Well_F15A  4085.9964 -999.25 -999.25  378.918793 -999.25 -999.25
#
#        RPCELM    RHOB  RPCEHM  CARB_FLAG  COAL_FLAG   KLOGH    PHIF  \
# 0     -999.25 -999.25 -999.25        NaN        NaN     NaN     NaN
# 1     -999.25 -999.25 -999.25        NaN        NaN     NaN     NaN
# 2     -999.25 -999.25 -999.25        NaN        NaN     NaN     NaN
# 3     -999.25 -999.25 -999.25        NaN        NaN     NaN     NaN
# 4     -999.25 -999.25 -999.25        NaN        NaN     NaN     NaN
# ...       ...     ...     ...        ...        ...     ...     ...
# 25384 -999.25 -999.25 -999.25        0.0    -999.25 -999.25 -999.25
# 25385 -999.25 -999.25 -999.25        0.0    -999.25 -999.25 -999.25
# 25386 -999.25 -999.25 -999.25        0.0    -999.25 -999.25 -999.25
# 25387 -999.25 -999.25 -999.25        0.0    -999.25 -999.25 -999.25
# 25388 -999.25 -999.25 -999.25        0.0    -999.25 -999.25 -999.25
#
#        SAND_FLAG      SW     VSH
# 0            NaN     NaN     NaN
# 1            NaN     NaN     NaN
# 2            NaN     NaN     NaN
# 3            NaN     NaN     NaN
# 4            NaN     NaN     NaN
# ...          ...     ...     ...
# 25384    -999.25 -999.25 -999.25
# 25385    -999.25 -999.25 -999.25
# 25386    -999.25 -999.25 -999.25
# 25387    -999.25 -999.25 -999.25
# 25388    -999.25 -999.25 -999.25
#
# [25389 rows x 17 columns]
# --------------------
# Well_F15B:
#            name      DEPTH    CALI          DT          GR    NPHI  RPCELM  \
# 0     Well_F15B  3146.9076 -999.25   56.974499 -999.250000 -999.25 -999.25
# 1     Well_F15B  3147.0600 -999.25   56.752201 -999.250000 -999.25 -999.25
# 1    -999.25   167.451797        NaN        NaN     NaN     NaN        NaN
# 2    -999.25  5000.000000        NaN        NaN     NaN     NaN        NaN
# 3    -999.25  5000.000000        NaN        NaN     NaN     NaN        NaN
# 4    -999.25  5000.000000        NaN        NaN     NaN     NaN        NaN
# ...      ...          ...        ...        ...     ...     ...        ...
# 4341 -999.25  -999.250000        0.0    -999.25 -999.25 -999.25    -999.25
# 4342 -999.25  -999.250000        0.0    -999.25 -999.25 -999.25    -999.25
# 4343 -999.25  -999.250000        0.0    -999.25 -999.25 -999.25    -999.25
# 4344 -999.25  -999.250000        0.0    -999.25 -999.25 -999.25    -999.25
# 4345 -999.25  -999.250000        0.0    -999.25 -999.25 -999.25    -999.25
#
#           SW     VSH
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ...      ...     ...
# 4341 -999.25 -999.25
# 4342 -999.25 -999.25
# 4343 -999.25 -999.25
# 4344 -999.25 -999.25
# 4345 -999.25 -999.25
#
# [4346 rows x 16 columns]

# %%
#%% `group`合并所有数据集

#　合并LAS和DLIS数据集
data_final_las = pd.concat([well_data[well_name] for well_name in well_data], axis=0,sort=False)
data_final_dlts = pd.concat([well_data_dlts[well_name] for well_name in well_data_dlts], axis=0,sort=False)
data_final = pd.concat([data_final_las, data_final_dlts], axis=0,sort=False)

# 统一电阻率列名
data_final.rename(columns = {'RPCEHM':'RM','RPCELM':'RD'}, inplace=True)
# 重新排序列
data_final = data_final.reindex(columns=['name', 'DEPTH', 'GR', 'BS', 'CALI', 'ROP', 'RHOB',
                                         'NPHI', 'RACEHM', 'RACELM', 'RM', 'RD', 'PEF', 'DT', 'DTS',
                                         'VCARB', 'VSH', 'PHIF', 'SW', 'KLOGH', 'KLOGV', 'SAND_FLAG',
                                         'CARB_FLAG', 'COAL_FLAG'])

# `delete`删除`out of range`异常值
data_final.loc[:,'NPHI'][data_final.loc[:,'NPHI']>0.6]=np.nan # # NPHI 大于 0.6 的值置为空值
data_final.loc[:,'NPHI'][data_final.loc[:,'NPHI']<-0.15]=np.nan
data_final.loc[:,'VSH'][data_final.loc[:,'VSH']<0]=np.nan
data_final.loc[:,'VSH'][data_final.loc[:,'VSH']>1]=np.nan
data_final.loc[:,'SW'][data_final.loc[:,'SW']<0]=np.nan
data_final.loc[:,'SW'][data_final.loc[:,'SW']>1]=np.nan
data_final.loc[:,'PHIF'][data_final.loc[:,'PHIF']>1.0]=np.nan
data_final.loc[:,'PHIF'][data_final.loc[:,'PHIF']<0.0]=np.nan

# %%
n_wells=data_final['name'].unique()
print(n_wells)
len(n_wells)
# Out:
# ['Well_F19A' 'Well_F19BT2' 'Well_F19SR' 'Well_F1A' 'Well_F1B' 'Well_F1C'
#  'Well_F1' 'Well_F11A' 'Well_F11B' 'Well_F11' 'Well_F11T2' 'Well_F12'
#  'Well_F15D' 'Well_F4' 'Well_F5' 'Well_F10' 'Well_F14' 'Well_F15'
#  'Well_F15A' 'Well_F15B' 'Well_F15C']
#  2           0.0  1.0000  0.7812  70.831481
#  3           0.0  1.0000  0.9155  31.452015
#  4           0.0  1.0000  0.9545   5.689620
#  ...         ...     ...     ...        ...
#  2921        0.0  0.8036  0.8552   0.518147
#  2922        0.0  0.8901  0.7930   0.478077
#  2923        0.0  1.0000  0.6836   0.725473
#  2924        0.0  1.0000  0.6778   0.709571
#  2925        0.0  0.9827  0.7033   0.754756
#
#  [2926 rows x 11 columns],
#  'Well_F19SR':             name      DEPTH      BWV      DT  KLOGH  KLOGV  PHIF  SAND_FLAG  \
#  1     Well_F19SR  3549.8532  0.08183  54.594    NaN    NaN   NaN        NaN
#  2     Well_F19SR  3550.0056  0.08183  54.594    NaN    NaN   NaN        NaN
#  3     Well_F19SR  3550.1580  0.08183  54.594    NaN    NaN   NaN        NaN
#  4     Well_F19SR  3550.3104  0.08183  54.594    NaN    NaN   NaN        NaN
#  5     Well_F19SR  3550.4628  0.08183  54.594    NaN    NaN   NaN        NaN
#  ...          ...        ...      ...     ...    ...    ...   ...        ...
#  7007  Well_F19SR  4617.5676  0.00000  40.000    0.0    NaN   0.0        0.0
#  7008  Well_F19SR  4617.7200  0.00000  40.000    0.0    NaN   0.0        0.0
#  7009  Well_F19SR  4617.8724  0.00000  40.000    0.0    NaN   0.0        0.0
#  7010  Well_F19SR  4618.0248  0.00000  40.000    0.0    NaN   0.0        0.0
#  7011  Well_F19SR  4618.1772  0.00000  40.000    0.0    NaN   0.0        0.0
#
#         SW  VSH
#  1     NaN  NaN
#  2     NaN  NaN
#  3     NaN  NaN
#  4     NaN  NaN
#  5     NaN  NaN
#  ...   ...  ...
#  7007  1.0  NaN
#  7008  1.0  NaN
#  7009  1.0  NaN
#  7010  1.0  NaN
#  7011  1.0  NaN
#
#  [7011 rows x 10 columns],
#  'Well_F1A':            name   DEPTH    BS  CALI  DT  DTS        GR  NPHI  PEF  RACEHM  \
#  801    Well_F1A   226.0  26.0   NaN NaN  NaN   13.8931   NaN  NaN  0.7782
#  802    Well_F1A   226.1  26.0   NaN NaN  NaN   16.8323   NaN  NaN  0.8146
#  803    Well_F1A   226.2  26.0   NaN NaN  NaN   19.4866   NaN  NaN  0.8264
#  804    Well_F1A   226.3  26.0   NaN NaN  NaN   21.0532   NaN  NaN  0.8416
#  805    Well_F1A   226.4  26.0   NaN NaN  NaN   23.6296   NaN  NaN  0.8546
#  ...         ...     ...   ...   ...  ..  ...       ...   ...  ...     ...
#  35281  Well_F1A  3674.0   8.5   NaN NaN  NaN  116.3081   NaN  NaN     NaN
#  35282  Well_F1A  3674.1   8.5   NaN NaN  NaN  116.6003   NaN  NaN     NaN
#  35283  Well_F1A  3674.2   8.5   NaN NaN  NaN  116.8855   NaN  NaN     NaN
#  35284  Well_F1A  3674.3   8.5   NaN NaN  NaN  113.8785   NaN  NaN     NaN
#  35285  Well_F1A  3674.4   8.5   NaN NaN  NaN  110.8716   NaN  NaN     NaN
#
#         ...      ROP  RPCEHM  RPCELM  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  SW  \
#  801    ...  10.1142  0.6478  0.7380        NaN    NaN   NaN        NaN NaN
#  802    ...  15.9918  0.8090  0.8258        NaN    NaN   NaN        NaN NaN
#  803    ...  21.8538  0.9507  0.9058        NaN    NaN   NaN        NaN NaN
#  804    ...  22.3173  1.0518  0.9406        NaN    NaN   NaN        NaN NaN
#  805    ...  22.7807  1.0162  0.9325        NaN    NaN   NaN        NaN NaN
#  ...    ...      ...     ...     ...        ...    ...   ...        ...  ..
#  35281  ...  10.7355     NaN     NaN        0.0    NaN   NaN        NaN NaN
#  35282  ...  10.7248     NaN     NaN        0.0    NaN   NaN        NaN NaN
#  35283  ...  10.7252     NaN     NaN        0.0    NaN   NaN        NaN NaN
#  35284  ...  10.7256     NaN     NaN        0.0    NaN   NaN        NaN NaN
#  35285  ...  10.7259     NaN     NaN        0.0    NaN   NaN        NaN NaN
#
#         VCARB     VSH
#  801      NaN     NaN
#  802      NaN     NaN
#  803      NaN     NaN
#  804      NaN     NaN
#  805      NaN     NaN
#  ...      ...     ...
#  35281    NaN  0.8516
#  35282    NaN  0.8540
#  35283    NaN  0.8563
#  35284    NaN  0.8324
#  35285    NaN  0.8086
#
#  [34223 rows x 22 columns],
#  'Well_F1B':            name   DEPTH    BS  CALI  DT  DTS       GR  NPHI  PEF  RACEHM  ...  \
#  24435  Well_F1B  2589.4  17.5   NaN NaN  NaN  73.4230   NaN  NaN  0.2521  ...
#  24436  Well_F1B  2589.5  17.5   NaN NaN  NaN  78.6534   NaN  NaN  0.2366  ...
#  24437  Well_F1B  2589.6  17.5   NaN NaN  NaN  82.2872   NaN  NaN  0.2222  ...
#  24438  Well_F1B  2589.7  17.5   NaN NaN  NaN  90.3382   NaN  NaN  0.2301  ...
#  24439  Well_F1B  2589.8  17.5   NaN NaN  NaN  96.3450   NaN  NaN  0.2400  ...
#  ...         ...     ...   ...   ...  ..  ...      ...   ...  ...     ...  ...
#  33108  Well_F1B  3456.7   8.5   NaN NaN  NaN  46.8000   NaN  NaN     NaN  ...
#  33109  Well_F1B  3456.8   8.5   NaN NaN  NaN  47.4863   NaN  NaN     NaN  ...
#  33110  Well_F1B  3456.9   8.5   NaN NaN  NaN  50.4962   NaN  NaN     NaN  ...
#  33111  Well_F1B  3457.0   8.5   NaN NaN  NaN  53.9392   NaN  NaN     NaN  ...
#  33112  Well_F1B  3457.1   8.5   NaN NaN  NaN  53.3564   NaN  NaN     NaN  ...
#
#             RPCEHM      RPCELM  CARB_FLAG  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  \
#  24435  59878.4727  96758.3672        NaN        NaN    NaN   NaN        NaN
#  24436  97543.4219  55767.8125        NaN        NaN    NaN   NaN        NaN
#  24437  97543.4219  84936.3359        NaN        NaN    NaN   NaN        NaN
#  24438  97543.4219  83289.7500        NaN        NaN    NaN   NaN        NaN
#  24439  97471.4219  96955.1797        NaN        NaN    NaN   NaN        NaN
#  ...           ...         ...        ...        ...    ...   ...        ...
#  33108         NaN         NaN        NaN        0.0    NaN   NaN        NaN
#  33109         NaN         NaN        NaN        0.0    NaN   NaN        NaN
#  39449        0.0 NaN    NaN  0.9962
#
#  [27354 rows x 20 columns],
#  'Well_F1':           name   DEPTH    BS  CALI  DT        GR  NPHI  PEF  RACEHM  RACELM  \
#  700    Well_F1   215.9  36.0   NaN NaN    8.7677   NaN  NaN  0.5405  0.2689
#  701    Well_F1   216.0  36.0   NaN NaN    7.9519   NaN  NaN  0.5642  0.3064
#  702    Well_F1   216.1  36.0   NaN NaN    6.5373   NaN  NaN  0.4250  0.2993
#  703    Well_F1   216.2  36.0   NaN NaN    5.8048   NaN  NaN  0.4877  0.3420
#  704    Well_F1   216.3  36.0   NaN NaN    6.3505   NaN  NaN  0.5296  0.2663
#  ...        ...     ...   ...   ...  ..       ...   ...  ...     ...     ...
#  34779  Well_F1  3623.8   8.5   NaN NaN  106.8823   NaN  NaN     NaN     NaN
#  34780  Well_F1  3623.9   8.5   NaN NaN  109.7547   NaN  NaN     NaN     NaN
#  34781  Well_F1  3624.0   8.5   NaN NaN  113.8085   NaN  NaN     NaN     NaN
#  34782  Well_F1  3624.1   8.5   NaN NaN  116.7465   NaN  NaN     NaN     NaN
#  34783  Well_F1  3624.2   8.5   NaN NaN  119.2240   NaN  NaN     NaN     NaN
#
#         ...      ROP  RPCEHM  RPCELM  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  SW  \
#  700    ...      NaN  0.1942  0.8712        NaN    NaN   NaN        NaN NaN
#  701    ...      NaN  0.1993  0.9572        NaN    NaN   NaN        NaN NaN
#  702    ...      NaN  0.1755  0.9183        NaN    NaN   NaN        NaN NaN
#  703    ...      NaN  0.1373  0.9427        NaN    NaN   NaN        NaN NaN
#  704    ...      NaN  0.1106  0.7757        NaN    NaN   NaN        NaN NaN
#  ...    ...      ...     ...     ...        ...    ...   ...        ...  ..
#  34779  ...  15.0267     NaN     NaN        NaN    NaN   NaN        NaN NaN
#  34780  ...  15.0186     NaN     NaN        NaN    NaN   NaN        NaN NaN
#  34781  ...  15.0105     NaN     NaN        NaN    NaN   NaN        NaN NaN
#  34782  ...  15.0183     NaN     NaN        NaN    NaN   NaN        NaN NaN
#  34783  ...  15.0260     NaN     NaN        NaN    NaN   NaN        NaN NaN
#
#         VCARB     VSH
#  700      NaN     NaN
#  701      NaN     NaN
#  702      NaN     NaN
#  703      NaN     NaN
#  704      NaN     NaN
#  ...      ...     ...
#  34779    0.0  0.7656
#  34780    0.0  0.7896
#  34781    0.0  0.8234
#  34782    0.0  0.8478
#  34783    0.0  0.8685
#
#  [33826 rows x 21 columns],
#  'Well_F11A':             name   DEPTH    BS  CALI  DT  DTS      GR  NPHI  PEF  RACEHM  ...  \
#  23771  Well_F11A  2565.6  17.5   NaN NaN  NaN  51.620   NaN  NaN   0.150  ...
#  23772  Well_F11A  2565.7  17.5   NaN NaN  NaN  55.199   NaN  NaN   0.148  ...
#  23773  Well_F11A  2565.8  17.5   NaN NaN  NaN  55.820   NaN  NaN   0.143  ...
#  23774  Well_F11A  2565.9  17.5   NaN NaN  NaN  56.663   NaN  NaN   0.135  ...
#  43642  Well_F11T2  4552.7   8.5   NaN NaN  NaN   NaN   NaN  NaN   1.016  ...
#  43643  Well_F11T2  4552.8   8.5   NaN NaN  NaN   NaN   NaN  NaN   0.994  ...
#  43644  Well_F11T2  4552.9   8.5   NaN NaN  NaN   NaN   NaN  NaN   0.975  ...
#  43645  Well_F11T2  4553.0   8.5   NaN NaN  NaN   NaN   NaN  NaN   0.967  ...
#
#            ROP  RPCEHM  RPCELM  CARB_FLAG  COAL_FLAG  KLOGH  PHIF  SAND_FLAG  \
#  520     8.488   2.194   1.692        NaN        NaN    NaN   NaN        NaN
#  521     8.498   2.346   1.824        NaN        NaN    NaN   NaN        NaN
#  522     8.471   2.393   1.918        NaN        NaN    NaN   NaN        NaN
#  523     8.444   2.327   1.991        NaN        NaN    NaN   NaN        NaN
#  524     8.417   2.405   2.112        NaN        NaN    NaN   NaN        NaN
#  ...       ...     ...     ...        ...        ...    ...   ...        ...
#  43641  14.957   1.112   1.114        NaN        0.0    NaN   NaN        NaN
#  43642  14.950   1.142   1.122        NaN        0.0    NaN   NaN        NaN
#  43643  14.943   1.139   1.112        NaN        0.0    NaN   NaN        NaN
#  43644  14.949   1.058   1.082        NaN        0.0    NaN   NaN        NaN
#  43645  14.954   0.985   1.064        NaN        0.0    NaN   NaN        NaN
#
#         SW  VSH
#  520   NaN  NaN
#  521   NaN  NaN
#  522   NaN  NaN
#  523   NaN  NaN
#  524   NaN  NaN
#  ...    ..  ...
#  43641 NaN  NaN
#  43642 NaN  NaN
#  43643 NaN  NaN
#  43644 NaN  NaN
#  43645 NaN  NaN
#
#  [42845 rows x 22 columns],
#  'Well_F12':            name      DEPTH  CARB_FLAG  COAL_FLAG         DT         GR  \
#  18781  Well_F12  3102.1020        0.0        0.0  77.930298  46.573299
#  18782  Well_F12  3102.2544        0.0        0.0  82.410500  47.280399
#  18783  Well_F12  3102.4068        0.0        0.0  85.986198  47.987499
#  18784  Well_F12  3102.5592        0.0        0.0  90.215897  51.266300
#  18785  Well_F12  3102.7116        0.0        0.0  89.835403  58.593700
#  ...         ...        ...        ...        ...        ...        ...
#  21427  Well_F12  3505.3524        0.0        0.0        NaN  80.523300
#  21428  Well_F12  3505.5048        0.0        NaN        NaN  79.315697
#  21429  Well_F12  3505.6572        0.0        NaN        NaN  79.495499
#  21430  Well_F12  3505.8096        0.0        NaN        NaN  79.675301
#  21431  Well_F12  3505.9620        0.0        NaN        NaN  79.855202
#
#           NPHI    RHOB  SAND_FLAG   KLOGH    PHIF      SW     VSH
#  18781  0.3124  2.2120        0.0  0.0010  0.2699  0.0205  0.3325
#  18782  0.3189  2.2151        0.0  0.0010  0.2680  0.0131  0.3389
#  18783  0.3254  2.2181        0.0  0.0010  0.2662  0.0104  0.3453
#  18784  0.3317  2.2200        0.0  0.0010  0.2651  0.0101  0.3751
#  18785  0.3375  2.2200        0.0  0.0010  0.2651  0.0124  0.4418
#  ...       ...     ...        ...     ...     ...     ...     ...
#  21427  0.2040  2.4323        1.0  0.1214  0.1354  0.8984  0.4736
